# %% [markdown]
# ## Date

# %% [markdown]
# **What information can be extracted from date:**
# * Day
# * Month
# * Year
# * Quarter
# * Semester
# * Day of Week
# * Weekend or not
# * Which decade's year
#
# **What information can be extracted from time:**
# * Hour
# * Minute
# * second

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("karthickveerakumar/orders-data")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 115k/115k [00:00<00:00, 418kB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/karthickveerakumar/orders-data/versions/1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Working with Date

# %%
# Converting obj to datetime format
df['order_date'] = pd.to_datetime(df['order_date'])

# %%
#Extract Year from date
df['year'] = df['order_date'].dt.year

# %%
#Extract month from date
df['month'] = df['order_date'].dt.month

# %%
#Extract month - name from date
df['monthName'] = df['order_date'].dt.month_name()

# %%
#Extract day from date (1,2,31)
df['day'] = df['order_date'].dt.day

# %%
#Extract day of week from date (monday, tuesday)
df['dow'] = df['order_date'].dt.dayofweek
#Extract day of week's name from date (monday, tuesday)
df['dow'] = df['order_date'].dt.day_name()

# %%
#chek if weekend
df['is_weekend'] = np.where(df['dow'].isin(['Sunday', 'Saturday']), 1, 0)

# %%
#extract week of the year
df['week'] = df['order_date'].dt.week

# %%
#extract quarter of the year
df['quarter'] = df['order_date'].dt.quarter

# %%
#extract semester of the year
df['sem'] = np.where(df['quarter'].isin([1,2]), 1, 2)

# %%
#Extract time between two dates
df['diff_days'] = (df['order_date'] - df['ship_date']).dt.days

# or
today = pd.to_datetime('today')
df['diff_days'] = (today - df['date']).dt.days

#for months passed
np.round((today - df['date']) / np.timedelta64(1, 'M'),0)

# %% [markdown]
# # Working with Time:

# %%
#Convert to date time
df['time'] = pd.to_datetime(df['time'])

# %%
#Extract hr, in, sec
df['hour'] = df['time'].dt.hour
df['min'] = df['time'].dt.minute
df['sec'] = df['time'].dt.second

# %%
#Given date and time , extract only time
df['time'] = df['date'].dt.time

# %%
#Time difference
today - df['time']

# %%
#Time difference in sec
(today - df['time']/np.timedelta64(1,'s'))

# %%
#Time difference in min
(today - df['time']/np.timedelta64(1,'m'))

# %%
#Time difference in hr
(today - df['time']/np.timedelta64(1,'h'))
